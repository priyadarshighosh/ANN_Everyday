# %% [markdown]
# # ADAM Optimizer
#
# # Adaptive Moment Estimator

# %% [markdown]
# Before

# %% [markdown]
# Batch Gradient

# %% [markdown]
# ![Screenshot 2024-09-17 231754.png](data:image/png;base64,...)

# %% [markdown]
# SGD - with Momentum
# Stochastic Gradient Descent

# %% [markdown]
# ![Screenshot 2024-09-17 232237.png](data:image/png;base64,...)

# %% [markdown]
# NAG  Momentum - Nesterov Accerlerated Gradient

# %% [markdown]
# ![Screenshot 2024-09-17 232716.png](data:image/png;base64,...)

# %% [markdown]
# ADAGRAD - Adaptive Gradient

# %% [markdown]
# ![Screenshot 2024-09-17 233024.png](data:image/png;base64,...)

# %% [markdown]
# RMS-PROP

# %% [markdown]
# ![Screenshot 2024-09-17 233205.png](data:image/png;base64,...)

# %% [markdown]
# # Mathematical Intuition for ADAM

# %% [markdown]
# ![Screenshot 2024-09-18 005809.png](data:image/png;base64,...)

# %% [markdown]
# ADAM takes care about the Learning Rate.

# %% [markdown]
# # ADAM behavior

# %% [markdown]
# ![Screenshot 2024-09-18 010606.png](data:image/png;base64,...)

# %% [markdown]
# There are other optimization techniques also like
# ADA DELTA
# ADA MAX
# Nadam
