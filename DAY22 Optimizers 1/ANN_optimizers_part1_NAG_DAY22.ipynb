# %% [markdown]
# <a href="https://colab.research.google.com/github/priyadarshighosh/ANN_Everyday/blob/main/DAY22%20Optimizers%201/ANN_optimizers_part1_NAG_DAY22.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # NAG -  Nesterov Accelerated Gradient

# %% [markdown]
# Batch Gradient Descent

# %% [markdown]
# ![Screenshot 2024-09-18 082716.png](data:image/png;base64,...)

# %% [markdown]
# SGD with Momentum

# %% [markdown]
# ![Screenshot 2024-09-18 082700.png](data:image/png;base64,...)

# %% [markdown]
# Nesterov  Accelerated  Gradient - NAG

# %% [markdown]
# ![Screenshot 2024-09-18 083542.png](data:image/png;base64,...)

# %% [markdown]
# In a Convex field , Momentum can work , But in a NON-Convex field , Momentum takes too many oscillations near the MINIMA .
#
# This is why we have made NAG , an improved Version of ON MOMENTUM .

# %% [markdown]
# MAIN FACTOR - DeCAYING FACTOR
#
# Change in the Weight so that loss can be minimum .

# %% [markdown]
# # MATHEMATICAL INTUITION FOR MOMENTUM

# %% [markdown]
# ![WhatsApp Image 2024-09-18 at 08.50.34.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# #  MATHEMATICAL INTUITION FOR NAG

# %% [markdown]
# ![WhatsApp Image 2024-09-18 at 08.50.34 (2).jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# # How NAG WORKS ...

# %% [markdown]
# ![WhatsApp Image 2024-09-18 at 08.50.34 (1).jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# NAG IS AN IMPROVEMENT OVER MOMENTUM
#
# IN THE WAY THAT BOTH OF THEM USE THE SAME
# "  IDEA OF MOMENTUM "

# %% [markdown]
# # DISADVANTAGES OF NAG

# %% [markdown]
# ![WhatsApp Image 2024-09-18 at 08.50.35.jpeg](data:image/jpeg;base64,...)
