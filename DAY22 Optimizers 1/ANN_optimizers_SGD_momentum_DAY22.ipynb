# %% [markdown]
# ![Screenshot 2024-09-16 144745.png](data:image/png;base64,...)![Screenshot 2024-09-16 144010.png](data:image/png;base64,...)![Screenshot 2024-09-16 143841.png](data:image/png;base64,...)![Screenshot 2024-09-16 143821.png](data:image/png;base64,...)![Screenshot 2024-09-16 143621.png](data:image/png;base64,...)![Screenshot 2024-09-16 143426.png](data:image/png;base64,...)![Screenshot 2024-09-16 143110.png](data:image/png;base64,...)![Screenshot 2024-09-16 141450.png](data:image/png;base64,...)

# %% [markdown]
# Weight vs loss - 2d graph is converted to 3d graph  taking another parameter into consideration
#
# It is then converted to Contour graph - a 2d graph
# differentiated by concentric circles , space between the circles and color of the graph
