# %% [markdown]
# # Archiitecture of Activation Function

# %% [markdown]
# ![Screenshot 2024-09-14 121309.png](data:image/png;base64,...)

# %% [markdown]
# # Different Activation Functions

# %% [markdown]
# ![Screenshot 2024-09-14 121400.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2024-09-14 040137.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2024-09-14 113311.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2024-09-14 120822.png](data:image/png;base64,...)
