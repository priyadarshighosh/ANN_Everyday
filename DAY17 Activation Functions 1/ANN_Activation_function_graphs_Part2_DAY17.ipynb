# %% [markdown]
# # Different Varients of  RELU  Activation Functions

# %% [markdown]
# RELU - Rectified Linear Unit

# %% [markdown]
# ![Screenshot 2024-09-14 133603.png](data:image/png;base64,...)

# %% [markdown]
# Comparison between Leaky RELU AND RELU

# %% [markdown]
# ![Screenshot 2024-09-14 133622.png](data:image/png;base64,...)

# %% [markdown]
# Paramiteric RELU

# %% [markdown]
# ![Screenshot 2024-09-14 134457.png](data:image/png;base64,...)

# %% [markdown]
# ELU - Exponential Linear UNIT -- Mainly used for Non-Linear DATA

# %% [markdown]
# ![Screenshot 2024-09-14 134854.png](data:image/png;base64,...)

# %% [markdown]
# BLUE  line - Graph of ELU Function
#
# Orange Line - Graph of Derivative of ELU Function

# %% [markdown]
# ![Screenshot 2024-09-14 135126.png](data:image/png;base64,...)

# %% [markdown]
# SELU

# %% [markdown]
# ![Screenshot 2024-09-14 135650.png](data:image/png;base64,...)

# %% [markdown]
# DERIVATIVE OF SELU

# %% [markdown]
# ![Screenshot 2024-09-14 140729.png](data:image/png;base64,...)
