# %% [markdown]
# # How Overfitting Works when we increase the no of Neurons and Layers

# %% [markdown]
# UNDERFITTING HAPPENING

# %% [markdown]
# ![Screenshot 2024-09-13 195341.png](data:image/png;base64,...)

# %% [markdown]
# UNDERFITTING BECOMES BETTER

# %% [markdown]
# ![Screenshot 2024-09-13 195430.png](data:image/png;base64,...)

# %% [markdown]
# CLOSE TO THE BEST CASE

# %% [markdown]
# ![Screenshot 2024-09-13 195458.png](data:image/png;base64,...)

# %% [markdown]
# BEST CASE SENARIO

# %% [markdown]
# ![Screenshot 2024-09-13 195857.png](data:image/png;base64,...)

# %% [markdown]
# OVERFITTING AS AF

# %% [markdown]
# ![Screenshot 2024-09-13 195520.png](data:image/png;base64,...)
