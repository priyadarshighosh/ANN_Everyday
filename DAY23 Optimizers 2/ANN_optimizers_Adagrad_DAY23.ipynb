# %% [markdown]
# # ADAGRAD
# #Adaptive Gradient Optimizer
#
# ---

# %% [markdown]
# If there are Spearse Values present that is
#
# 0 are abundantly present in the datsent , the graph will look ELONGATED .
#
# We use ADAGRAD to solve this
#
# # Elongated Bowl Problem

# %% [markdown]
# ![Screenshot 2024-09-17 154658.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2024-09-17 155917.png](data:image/png;base64,...)

# %% [markdown]
# Both Batch Gradient and Momentum does not perform well , if the graph is elongated because Sparse values are abundantly present in the dataset .

# %% [markdown]
# ![Screenshot 2024-09-17 200231.png](data:image/png;base64,...)

# %% [markdown]
# As More inputs going to be Zero thats why on an AVERAGE CHANGE IN THE WEIGHT UPDATE is SMALL
#
# but BIAS DOESNOT DEPEND ON THE InPUT
# thats why , we get large updates of Biases
#
# THIS IS BAD ,  we want the update to take place at a similar level

# %% [markdown]
# Thats why we use ADAGRAD of change the LEARNING RATE of each parameter ( weights / biases ) differently

# %% [markdown]
# # Mathematical Formula for Adagrad

# %% [markdown]
# ![WhatsApp Image 2024-09-17 at 20.14.51.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# # Disadvantage Of ADAGRAD

# %% [markdown]
# It doesnot converge as learning rate becomes very small , it doesnot work for Neural Network .
