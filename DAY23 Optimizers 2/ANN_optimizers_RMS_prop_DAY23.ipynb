# %% [markdown]
# <a href="https://colab.research.google.com/github/priyadarshighosh/ANN_Everyday/blob/main/DAY23%20Optimizers%202/ANN_optimizers_RMS_prop_DAY23.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # RMS Prop
# # Root Mean Square Propagation
#
# ---

# %% [markdown]
# It is an improvement over Adagrad .

# %% [markdown]
# ![WhatsApp Image 2024-09-18 at 09.29.38.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# Adagrad Optimizer is Used when there is Sparse Data present abundantly in the input .
#
# Sparse data in the sense , alot of 0 s are present .

# %% [markdown]
# What do we do -- We decrease the learning rate so it can converge

# %% [markdown]
# DISADVANTAGE - ADAGRAD DOESNOT CONVERGE IT GOES CLOSE TO THE GLOBAL MINIMA BUT IT DOESNOT CONVERGE . LOL

# %% [markdown]
# # MATHEMATICAL INTUITION FOR RMS PROP

# %% [markdown]
# This is kinda like exponential weighted average .
#
# But here we,
#
# VELOCITY AS beta of the previous velocity and 1-beta of the weight_change sq
#
# This is the only difference between RMS PROP AND ADAGRAD

# %% [markdown]
# ![WhatsApp Image 2024-09-18 at 09.29.38 (1).jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# WE GIVE MORE VALUES TO THE RECENT ( LAST VELOCITY )
#
# AND LESS WEIGHTAGE TO THE TOTAL WEIGHT_CHANGE SQ

# %% [markdown]
# ![WhatsApp Image 2024-09-18 at 09.29.38 (2).jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# DISADVANTAGES OF RMS PROP

# %% [markdown]
# SIKE!!! - It doesnot have disadvantages , it was the most used optimizer before ADAM

# %% [markdown]
# ![WhatsApp Image 2024-09-18 at 09.29.39.jpeg](data:image/jpeg;base64,...)
